# %%
import csv
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
# %matplotlib inline
import seaborn as sns
plt.rcParams['figure.figsize'] = (15.0, 10.0)

# %%
moods = pd.read_csv('angry_moods.csv')
moods["Athlete"]= np.where(moods['Sports']==1,'Athlete','Non-Athlete')
moods
# Out:
#     Gender  Sports  Anger-Out  Anger-In  Control-Out  Control-In  \
# 0        2       1         18        13           23          20
# 1        2       1         14        17           25          24
# 2        2       1         13        14           28          28
# 3        2       1         17        24           23          23
# 4        1       1         16        17           26          28
# ..     ...     ...        ...       ...          ...         ...
# 73       2       1         14        11           18          15
# 74       2       1         10        18           30          32
# 75       2       1         11        14           29          24
# 76       1       1         15        17           20          18
# 77       2       1         15        17           24          26
#
#     Anger_Expression  Athlete
# 0                 36  Athlete
# 1                 30  Athlete
# 2                 19  Athlete
# 3                 43  Athlete
# ...

# %%
ax = sns.boxplot(x="Athlete", y="Control-In", data=moods)

# %%
df = moods[moods.Athlete=="Athlete"]
bincount = 10
plt.hist(df['Control-In'], alpha=0.5,  bins=bincount)

df = moods[moods.Athlete=="Non-Athlete"]

plt.hist(df['Control-In'], alpha=0.5, bins=bincount)
plt.legend(["Athlete", "Non-Athlete"])

# %%
ax = sns.boxplot(x="Athlete", y="Anger-Out", data=moods)

# %%
print("All Anger Out: ", scipy.stats.skew(moods["Anger-Out"]))
print("Athlete Anger Out: ", scipy.stats.skew(moods[moods.Athlete=="Athlete"]["Anger-Out"]))
print("Non-Athlete Anger Out: ", scipy.stats.skew(moods[moods.Athlete=="Non-Athlete"]["Anger-Out"]))
# Out:
# All Anger Out:  0.5743309743227966
# Athlete Anger Out:  0.7718026863314305
# Non-Athlete Anger Out:  0.4056754433279569

# %%
scipy.stats.range(moods["Anger-Out"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-052378a8b43c> in <module>
# ----> 1 scipy.stats.range(moods["Anger-Out"])
#
# AttributeError: module 'scipy.stats' has no attribute 'range'

# %%
dfmax = max(moods["Anger-In"])
dfmin = min(moods["Anger-In"])
print("Anger In Range: ", dfmax - dfmin, "Max: ", dfmax, "Min: ", dfmin)
# Out:
# Anger In Range:  21 Max:  31 Min:  10

# %%
moods['Anger-In'].describe()
# Out:
# count    78.000000
# mean     18.576923
# std       4.697386
# min      10.000000
# 25%      15.000000
# 50%      18.500000
# 75%      22.000000
# max      31.000000
# Name: Anger-In, dtype: float64

# %%
dfstats = moods['Anger-In'].describe()
print("Interquartile Range:", dfstats["75%"]-dfstats["25%"])
# Out:
# Interquartile Range: 7.0
